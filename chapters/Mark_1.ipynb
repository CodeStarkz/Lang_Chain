# %%
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
import os
from dotenv import load_dotenv



load_dotenv()
gemini_key = os.getenv("GEMINI_API_KEY")
file_path= "/Users/abhisheksingh/Lang_Chain/chat_history.txt"

# %%
Text_loader_Object = TextLoader(
    file_path = file_path,
    encoding = "utf-8"
)
loaded_document = Text_loader_Object.load()

# %%
print(Text_loader_Object.load())
# Out:
# [Document(metadata={'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}, page_content='Here are 5 interesting facts about Artificial Intelligence (AI):\n\nAI can generate novel images, akin to "dreaming," by learning from vast datasets.\nBeyond the Turing Test, AI intelligence is measured by specific capabilities like problem-solving and language understanding.\nAI is already assisting in medical diagnoses, sometimes matching or surpassing human accuracy.\nAI demonstrates creativity by composing music, writing poetry, and generating computer code.\nThe concept of AI is ancient, with its formal term coined in 1956, but the idea of intelligent machines predates it significantly.')]

# %%
TextSplitter_object = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 12
)

# %%
splited_document = TextSplitter_object.split_documents(loaded_document)

# %%
print(splited_document[1].page_content)
# Out:
# AI can generate novel images, akin to "dreaming," by learning from vast datasets.

# %%
print(len(splited_document))
# Out:
# 8

# %%
for i in range(9):
    print(splited_document[i].page_content)
# Out:
# Here are 5 interesting facts about Artificial Intelligence (AI):
# AI can generate novel images, akin to "dreaming," by learning from vast datasets.
# Beyond the Turing Test, AI intelligence is measured by specific capabilities like problem-solving
# and language understanding.
# AI is already assisting in medical diagnoses, sometimes matching or surpassing human accuracy.
# AI demonstrates creativity by composing music, writing poetry, and generating computer code.
# The concept of AI is ancient, with its formal term coined in 1956, but the idea of intelligent
# intelligent machines predates it significantly.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 for i in range(9):
# ----> 2     print(splited_document[i].page_content)
#
# IndexError: list index out of range

# %%
for i in range(8):
    print(splited_document[i].metadata)
# Out:
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
# {'source': '/Users/abhisheksingh/Lang_Chain/chat_history.txt'}
