# %% [markdown]
# # Vector Store
# ## A system designed to store and retrive data represented as numerical
# # Key Features
# ## Storing Vectors
# ## Retrieving Vectors
# ## Symentic Searching
# ## Indexing
# ## CURD Operations

# %%
from langchain_chroma import chroma

# %% [markdown]
# # Retriver
# ## A retriver is a component in langchain that fetches relevant documents from a data source in response of a user querry.
# ## There are multiple types of retriver in Langchain (Wikipedia retirvers, Vector Retrivers, Archive retrivers)
# ## All retrivers are runnables
